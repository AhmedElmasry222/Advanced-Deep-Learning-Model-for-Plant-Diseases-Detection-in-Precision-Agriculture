# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
import os
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import glob as gb
import cv2
import keras
from keras.applications import imagenet_utils
from tensorflow.keras.optimizers import SGD,Adam

from keras import backend as K
from keras.models import Sequential, Model,load_model
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Dropout, Input, Add,DepthwiseConv2D, Dense, Activation,SeparableConv1D,GlobalAveragePooling2D, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D,Dropout
from keras.preprocessing import image
from keras.initializers import glorot_uniform

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score


import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle
import itertools

#Model Graphs
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
# Out:
# 2024-02-17 20:37:13.383584: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-17 20:37:13.383708: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-17 20:37:13.501929: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_path='/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Training/'
test_path='/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Testing/'
val_path='/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256/Validation/'

# %%
traingen = tf.keras.preprocessing.image.ImageDataGenerator(
                     rescale=1./255,
                    #rotation_range=45, 
                    #width_shift_range=.15, 
                    #height_shift_range=.15,
                    #horizontal_flip=True, 
                    #zoom_range=0.5
)
testgen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)
validgen =tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

# %%
classes=[dir for dir in os.listdir(val_path) if "Tomato" in dir]

# %%
classes
# Out:
# []

# %%
train_ds=traingen.flow_from_directory(batch_size=32,directory=train_path,shuffle=True,
                                                 target_size=(224,224),class_mode='categorical',
                                      #classes=[dir for dir in os.listdir(train_path) if "Tomato" in dir]
                                     
                                     )
test_ds=traingen.flow_from_directory(batch_size=32,directory=test_path,shuffle=False,target_size=(224,224), 
                                                 class_mode='categorical',
                                                 
                                    
                                    )

val_ds=traingen.flow_from_directory(batch_size=32,directory=val_path,shuffle=True,target_size=(224,224), 
                                                 class_mode='categorical',
                                   )
# Out:
# Found 3251 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Found 416 images belonging to 3 classes.

# %%
from keras import backend

# %%
input_shape=(224,224,3)
input = layers.Input(shape=input_shape)
x=Conv2D(16,(2,2),activation="relu",padding='same')(input)
x=MaxPool2D(2,2)(x)


x=Conv2D(32,(2,2),activation="relu",padding='same')(x)
x=MaxPool2D(2,2)(x)
x=Dropout(.2)(x)

x=Conv2D(32,(2,2),activation="relu",padding='same')(x)
x=MaxPool2D(2,2)(x)
x=Dropout(.2)(x)

x=Conv2D(128,(2,2),activation="relu",padding='same')(x)
x=MaxPool2D(2,2)(x)
x=Dropout(.2)(x)
x=Flatten()(x)
x=Dense(500,activation="relu")(x)
x=Dropout(.2)(x)

x=Dense(3,activation="softmax")(x)
model=Model(input,x)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      208
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      2080
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  dropout (Dropout)           (None, 56, 56, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)        4128
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 28, 28, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       16512
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 500)               12544500
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 3)                 1503
#
# =================================================================
# Total params: 12568931 (47.95 MB)
# Trainable params: 12568931 (47.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)

# %%
def step_decay(epoch):
    initial_lrate = 0.1
    drop = 0.5
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
import math
lrate = LearningRateScheduler(step_decay)
callbacks_list = [lrate]

# %%
model.compile(
    loss=keras.losses.CategoricalCrossentropy(),optimizer = keras.optimizers.Adam()
,
    metrics=[keras.metrics.CategoricalAccuracy(name="accuracy")],
)

# %%
history = model.fit(train_ds,validation_data=val_ds,batch_size=32,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 2024-02-17 20:37:29.203767: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1708202251.838862      89 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 102/102 [==============================] - 21s 155ms/step - loss: 1.1376 - accuracy: 0.4574 - val_loss: 1.0831 - val_accuracy: 0.3221
# Epoch 2/50
# 102/102 [==============================] - 8s 74ms/step - loss: 0.9383 - accuracy: 0.5595 - val_loss: 0.9181 - val_accuracy: 0.5457
# Epoch 3/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.6907 - accuracy: 0.7284 - val_loss: 0.7414 - val_accuracy: 0.5986
# Epoch 4/50
# 102/102 [==============================] - 8s 76ms/step - loss: 0.4985 - accuracy: 0.8078 - val_loss: 0.6285 - val_accuracy: 0.6827
# Epoch 5/50
# 102/102 [==============================] - 8s 83ms/step - loss: 0.3625 - accuracy: 0.8604 - val_loss: 0.6423 - val_accuracy: 0.6779
# Epoch 6/50
# 102/102 [==============================] - 8s 83ms/step - loss: 0.3281 - accuracy: 0.8782 - val_loss: 0.8517 - val_accuracy: 0.6442
# Epoch 7/50
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2760 - accuracy: 0.9037 - val_loss: 0.3898 - val_accuracy: 0.8606
# Epoch 8/50
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2472 - accuracy: 0.9139 - val_loss: 0.3291 - val_accuracy: 0.8894
# Epoch 9/50
# 102/102 [==============================] - 8s 76ms/step - loss: 0.2120 - accuracy: 0.9305 - val_loss: 0.3323 - val_accuracy: 0.8870
# Epoch 10/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.2002 - accuracy: 0.9302 - val_loss: 0.2478 - val_accuracy: 0.9111
# Epoch 11/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.1653 - accuracy: 0.9416 - val_loss: 0.2955 - val_accuracy: 0.9014
# Epoch 12/50
# 102/102 [==============================] - 7s 70ms/step - loss: 0.1535 - accuracy: 0.9462 - val_loss: 0.3558 - val_accuracy: 0.8702
# Epoch 13/50
# 102/102 [==============================] - 8s 73ms/step - loss: 0.1431 - accuracy: 0.9508 - val_loss: 0.2649 - val_accuracy: 0.9087
# Epoch 14/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.1265 - accuracy: 0.9569 - val_loss: 0.2329 - val_accuracy: 0.9183
# Epoch 15/50
# 102/102 [==============================] - 8s 74ms/step - loss: 0.0860 - accuracy: 0.9686 - val_loss: 0.2572 - val_accuracy: 0.8966
# Epoch 16/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.1010 - accuracy: 0.9634 - val_loss: 0.2631 - val_accuracy: 0.9207
# Epoch 17/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0878 - accuracy: 0.9705 - val_loss: 0.2101 - val_accuracy: 0.9207
# Epoch 18/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0706 - accuracy: 0.9723 - val_loss: 0.1922 - val_accuracy: 0.9231
# Epoch 19/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.0680 - accuracy: 0.9760 - val_loss: 0.2510 - val_accuracy: 0.9207
# Epoch 20/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0737 - accuracy: 0.9757 - val_loss: 0.2529 - val_accuracy: 0.9038
# Epoch 21/50
# 102/102 [==============================] - 7s 69ms/step - loss: 0.0706 - accuracy: 0.9754 - val_loss: 0.2384 - val_accuracy: 0.9327
# Epoch 22/50
# 102/102 [==============================] - 7s 70ms/step - loss: 0.0800 - accuracy: 0.9708 - val_loss: 0.2382 - val_accuracy: 0.9207
# Epoch 23/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.0799 - accuracy: 0.9680 - val_loss: 0.2291 - val_accuracy: 0.9327
# Epoch 24/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0333 - accuracy: 0.9892 - val_loss: 0.2293 - val_accuracy: 0.9255
# Epoch 25/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 0.2562 - val_accuracy: 0.9279
# Epoch 26/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.0342 - accuracy: 0.9874 - val_loss: 0.3473 - val_accuracy: 0.9038
# Epoch 27/50
# 102/102 [==============================] - 7s 68ms/step - loss: 0.0667 - accuracy: 0.9766 - val_loss: 0.2330 - val_accuracy: 0.9399
# Epoch 28/50
# 102/102 [==============================] - 7s 68ms/step - loss: 0.0497 - accuracy: 0.9828 - val_loss: 0.2719 - val_accuracy: 0.9014
# Epoch 29/50
# 102/102 [==============================] - 8s 73ms/step - loss: 0.0394 - accuracy: 0.9859 - val_loss: 0.2204 - val_accuracy: 0.9351
# Epoch 30/50
# 102/102 [==============================] - 7s 67ms/step - loss: 0.0233 - accuracy: 0.9914 - val_loss: 0.1503 - val_accuracy: 0.9495
# Epoch 31/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0313 - accuracy: 0.9886 - val_loss: 0.2140 - val_accuracy: 0.9471
# Epoch 32/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.0352 - accuracy: 0.9898 - val_loss: 0.2410 - val_accuracy: 0.9471
# Epoch 33/50
# 102/102 [==============================] - 7s 67ms/step - loss: 0.0709 - accuracy: 0.9760 - val_loss: 0.2208 - val_accuracy: 0.9279
# Epoch 34/50
# 102/102 [==============================] - 7s 68ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.2438 - val_accuracy: 0.9327
# Epoch 35/50
# 102/102 [==============================] - 7s 69ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.2059 - val_accuracy: 0.9375
# Epoch 36/50
# 102/102 [==============================] - 8s 75ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.2891 - val_accuracy: 0.9423
# Epoch 37/50
# 102/102 [==============================] - 7s 70ms/step - loss: 0.0395 - accuracy: 0.9877 - val_loss: 0.2022 - val_accuracy: 0.9351
# Epoch 38/50
# 102/102 [==============================] - 8s 75ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.2675 - val_accuracy: 0.9351
# Epoch 39/50
# 102/102 [==============================] - 7s 73ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.3001 - val_accuracy: 0.9375
# Epoch 40/50
# 102/102 [==============================] - 7s 69ms/step - loss: 0.0490 - accuracy: 0.9852 - val_loss: 0.2412 - val_accuracy: 0.9351
# Epoch 41/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.0529 - accuracy: 0.9822 - val_loss: 0.2264 - val_accuracy: 0.9447
# Epoch 42/50
# 102/102 [==============================] - 7s 70ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.3027 - val_accuracy: 0.9279
# Epoch 43/50
# 102/102 [==============================] - 7s 69ms/step - loss: 0.0571 - accuracy: 0.9812 - val_loss: 0.2112 - val_accuracy: 0.9447
# Epoch 44/50
# 102/102 [==============================] - 7s 72ms/step - loss: 0.0212 - accuracy: 0.9923 - val_loss: 0.2559 - val_accuracy: 0.9303
# Epoch 45/50
# 102/102 [==============================] - 7s 67ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.1746 - val_accuracy: 0.9471
# Epoch 46/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0139 - accuracy: 0.9966 - val_loss: 0.2752 - val_accuracy: 0.9399
# Epoch 47/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.2616 - val_accuracy: 0.9351
# Epoch 48/50
# 102/102 [==============================] - 7s 71ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.2732 - val_accuracy: 0.9399
# Epoch 49/50
# 102/102 [==============================] - 7s 68ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.2292 - val_accuracy: 0.9399
# Epoch 50/50
# 102/102 [==============================] - 7s 69ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 0.2733 - val_accuracy: 0.9495

# %%
model.save_weights('/kaggle/working/model1.h5')

# %%
from tensorflow.keras.utils import to_categorical
y_pred = model.predict_generator(test_ds)
y_pred2= to_categorical(np.argmax(y_pred, axis=1), 3)

y_test= to_categorical(test_ds.labels, 3)

# Using it in AUC
y_pred1=(np.argmax(y_pred, axis=1))
y_test1=(np.argmax(y_test, axis=1))

# %%
# Computing the Accuracy Score  : ((TP + TN) / float(TP + TN + FP + FN))
def Accuracy(y_test , y_pred):
    AccScore = accuracy_score(y_test, y_pred, normalize=True)
    return AccScore

# %%
#Computing the Precision metric (Some times called Specificity): #(True Positives / float(True Positives + False Posivites))  
def macro_precision(y_test , y_pred):
    PrecisionScore = precision_score(y_test, y_pred, average='macro') 
    return PrecisionScore

# %%
#Computing the Recall Score : (Some times called Sensitivity) (TP / float(TP + FN))   1 / 1+2  
def macro_recall(y_test , y_pred):
    RecallScore = recall_score(y_test, y_pred, average='macro') 
    return  RecallScore

# %%
#Computing the F1 Score  : 2 * (precision * recall) / (precision + recall)
def macro_F1Score(y_test , y_pred):
    F1Score = f1_score(y_test, y_pred, average='macro') 
    return F1Score

# %%
from sklearn.metrics import roc_auc_score

# Calculating Area under the curve
def AUC(actual_class, pred_class, average = "micro"):
    
    #Making a set of all the unique classes 
    unique_class = set(actual_class)
    roc_auc_dict = {}
    for per_class in unique_class:
        
        #Making a list of all the classes except the current class 
        other_class = [x for x in unique_class if x != per_class]

        #Making the current class with label 1 and all other classes as a label 0
        new_actual_class = [0 if x in other_class else 1 for x in actual_class]
        new_pred_class = [0 if x in other_class else 1 for x in pred_class]

        # Calculating the roc_auc_score
        roc_auc = roc_auc_score(new_actual_class, new_pred_class, average = average)
        roc_auc_dict[per_class] = roc_auc

    return roc_auc_dict

# %%
print("***** Model Evaluations Details ******** \n")
print("Test loss, Test acc : " , model.evaluate_generator(test_ds)) 
print("******************************")
print("Accurayc  : " , Accuracy(test_ds.classes , y_pred1)) 
print("******************************")
print("Precision Score is : " , macro_precision(test_ds.classes , y_pred1))
print("******************************")
print("Recall Scores is : " , macro_recall(test_ds.classes , y_pred1))
print("******************************")
print('F1 Score is : ', macro_F1Score(test_ds.classes , y_pred1))
print("******************************")
print('AUC Score is : ' , AUC(test_ds.classes, y_pred1))
# Out:
# ***** Model Evaluations Details ********
#
# Test loss, Test acc :  [0.30039742588996887, 0.9456790089607239]
# ******************************
# Accurayc  :  0.945679012345679
# ******************************
# Precision Score is :  0.9433557870684585
# ******************************
# Recall Scores is :  0.9468419886998666
# ******************************
# F1 Score is :  0.9449554069119287
# ******************************
# AUC Score is :  {0: 0.9475308641975311, 1: 0.9606387109299165, 2: 0.9711476466795617}

# %%
labels=["Class 0","Class 1","Class 2"]

# %%
from sklearn.metrics import classification_report

print(classification_report(test_ds.classes, y_pred1,target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.94      0.93      0.94       162
#      Class 1       0.92      0.95      0.93       102
#      Class 2       0.97      0.96      0.96       141
#
#     accuracy                           0.95       405
#    macro avg       0.94      0.95      0.94       405
# weighted avg       0.95      0.95      0.95       405

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
plt.style.library['seaborn-whitegrid']
# Out:
# RcParams({'axes.axisbelow': True,
#           'axes.edgecolor': '.8',
#           'axes.facecolor': 'white',
#           'axes.grid': True,
#           'axes.labelcolor': '.15',
#           'axes.linewidth': 1.0,
#           'figure.facecolor': 'white',
#           'font.family': ['sans-serif'],
#           'font.sans-serif': ['Arial',
#                               'Liberation Sans',
#                               'DejaVu Sans',
#                               'Bitstream Vera Sans',
#                               'sans-serif'],
#           'grid.color': '.8',
#           'grid.linestyle': '-',
#           'image.cmap': 'Greys',
#           'legend.frameon': False,
#           'legend.numpoints': 1,
#           'legend.scatterpoints': 1,
#           'lines.solid_capstyle': <CapStyle.round: 'round'>,
#           'text.color': '.15',
#           'xtick.color': '.15',
#           'xtick.direction': 'out',
#           'xtick.major.size': 0.0,
#           'xtick.minor.size': 0.0,
#           'ytick.color': '.15',
#           'ytick.direction': 'out',
#           'ytick.major.size': 0.0,
#           'ytick.minor.size': 0.0})

# %%
font = {'family' : 'normal',
    'weight' : 'bold',
    'size'   : 12}
plt.rc('font', **font)

# %%
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
def plot_roc_curve(y_test,y_pred):
    n_classes=3
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    lw=2
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
    plt.figure(figsize=(10, 10))
    plt.plot(fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,)

    plt.plot(fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)
    colors = cycle(["aqua", "darkorange", "cornflowerblue",'#9e9e9e','#b19a7e','#CD5C5C','#DFFF00',
                   '#DE3163','#ff4d4d','#CCCCFF','#800080','#4F1D25','#ccffcc','#ff0040'
                   ,'#4000ff','#0080ff','#ff8000','#666600','#b37700','#00b3b3','#003300','#FFC300','#A6F7BD',
                   '#A6BDF7','#CAA6F7','#F7A6AC','#ADF7A6','#F5F7A6','#F7CCA6','#EE4949',
                    '#DEA41F','#334471','#33716F','#343371','#772CE3','#B8BF20','#666B01','#0B6B01',
                    '#F4B708','#179690'
                   ])

    for i, color in zip(range(n_classes), colors):
        plt.plot(
           fpr[i],
           tpr[i],
           color=color,
           lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})".format(i, roc_auc[i]),
    )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend(bbox_to_anchor=(1, 1))
    plt.show()

# %%
def Acc_Loss_Graph(history):
    # converting hsitory to dataframe
    pd.DataFrame(history.history)

    pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
    plt.title('Training Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('accuracy')

    pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

# %%
labels=np.array(["Class 0","Class 1","Class 2"])

# %%
def Confusion_Matrix(y_test , y_pred):
    fig, ax = plt.subplots(figsize=(5,5))

    #cnf_matrix = confusion_matrix()
    disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred,display_labels=labels,ax=ax,xticks_rotation='vertical'
                                                  ,cmap="Blues")

# %%
Acc_Loss_Graph(history)

# %%
plot_roc_curve(y_test,y_pred2)

# %%
Confusion_Matrix(test_ds.classes , y_pred1)

# %%
target_name={0:"Class 0",1:"Class 1",2:"Class 2",3:"Class 3",4:"Class 4",5:"Class 5",6:"Class 6",7:"Class 7",8:"Class 8",9:"Class 9",
             10:"Class 10",11:"Class 11",12:"Class 12",
               13:"Class 13",14:"Class 14",15:"Class 15",16:"Class 16",17:"Class 17",18:"Class 18",19:"Class 19",20:"Class 20",21:"Class 21",
             22:"Class 22",23:"Class 23",24:"Class 24",25:"Class 25",26:"Class 26",27:"Class 27",28:"Class 28",29:"Class 29",30:"Class 30",31:"Class 31",32:"Class 32",33:"Class 33",34:"Class 34"
                ,35:"Class 35",36:"Class 36",37:"Class 37"}

# %%
from sklearn.manifold import TSNE
tsne1 = TSNE(random_state = 42, n_components=2, verbose=0, perplexity=40, n_iter=300).fit_transform(y_pred)

# %%
# create dataframe
cps_df = pd.DataFrame(columns=['CP1', 'CP2', 'target'],
                       data=np.column_stack((tsne1, 
                                            y_test1)))# cast targets column to int
cps_df.loc[:, 'target'] = cps_df.target.astype(int)
cps_df.loc[:, 'target'] = cps_df.target.map(target_name)

# %%
import seaborn as sns
d = {'color': ["aqua", "darkorange", "cornflowerblue",'#9e9e9e','#b19a7e','#CD5C5C','#DFFF00',
                   '#DE3163','#ff4d4d','#CCCCFF','#800080','#4F1D25','#ccffcc','#ff0040'
                   ,'#4000ff','#0080ff','#ff8000','#666600','#b37700','#00b3b3','#003300','#FFC300','#A6F7BD',
                   '#A6BDF7','#CAA6F7','#F7A6AC','#ADF7A6','#F5F7A6','#F7CCA6','#EE4949',
                    '#DEA41F','#334471','#33716F','#343371','#772CE3','#B8BF20','#666B01','#0B6B01',
                    '#F4B708','#179690'] }
grid = sns.FacetGrid(cps_df, hue="target",hue_kws=d, height=8)
grid.map(plt.scatter, 'CP1', 'CP2').add_legend()
